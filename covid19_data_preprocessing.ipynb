# %% [markdown]
# # 라이브러리 import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from datetime import datetime, timedelta
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 데이터 수집

# %%
df_raw = pd.read_csv('covid.csv',dtype={'id':str})

# %%
df_raw.head()
# Out:
#        id  sex  patient_type  entry_date date_symptoms   date_died  intubed  \
# 0  16169f    2             1  04-05-2020    02-05-2020  9999-99-99       97
# 1  1009bf    2             1  19-03-2020    17-03-2020  9999-99-99       97
# 2  167386    1             2  06-04-2020    01-04-2020  9999-99-99        2
# 3  0b5948    2             2  17-04-2020    10-04-2020  9999-99-99        2
# 4  0d01b5    1             2  13-04-2020    13-04-2020  22-04-2020        2
#
#    pneumonia  age  pregnancy  ...  inmsupr  hypertension  other_disease  \
# 0          2   27         97  ...        2             2              2
# 1          2   24         97  ...        2             2              2
# 2          2   54          2  ...        2             2              2
# 3          1   30         97  ...        2             2              2
# 4          2   60          2  ...        2             1              2
#
#    cardiovascular  obesity  renal_chronic  tobacco  contact_other_covid  \
# 0               2        2              2        2                    2
# 1               2        2              2        2                   99
# 2               2        1              2        2                   99
# 3               2        2              2        2                   99
# 4               1        2              2        2                   99
#
#    covid_res  icu
# 0          1   97
# 1          1   97
# 2          1    2
# 3          1    2
# 4          1    2
#
# [5 rows x 23 columns]

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 566602 entries, 0 to 566601
# Data columns (total 23 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   566602 non-null  object
#  1   sex                  566602 non-null  int64
#  2   patient_type         566602 non-null  int64
#  3   entry_date           566602 non-null  object
#  4   date_symptoms        566602 non-null  object
#  5   date_died            566602 non-null  object
#  6   intubed              566602 non-null  int64
#  7   pneumonia            566602 non-null  int64
#  8   age                  566602 non-null  int64
#  9   pregnancy            566602 non-null  int64
#  10  diabetes             566602 non-null  int64
#  11  copd                 566602 non-null  int64
#  12  asthma               566602 non-null  int64
#  13  inmsupr              566602 non-null  int64
#  14  hypertension         566602 non-null  int64
#  15  other_disease        566602 non-null  int64
#  16  cardiovascular       566602 non-null  int64
#  17  obesity              566602 non-null  int64
#  18  renal_chronic        566602 non-null  int64
#  19  tobacco              566602 non-null  int64
#  20  contact_other_covid  566602 non-null  int64
#  21  covid_res            566602 non-null  int64
#  22  icu                  566602 non-null  int64
# dtypes: int64(19), object(4)
# memory usage: 99.4+ MB

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# #### 1. patient_type=1 제거
# - patient_type=1 생존율이 약 99%로 모델링 적합하지 않다

# %%
df1 = df_raw[df_raw.patient_type != 1] 
df1['patient_type'].head(20)
# Out:
# 2     2
# 3     2
# 4     2
# 5     2
# 6     2
# 9     2
# 10    2
# 12    2
# 21    2
# 30    2
# 31    2
# 33    2
# 36    2
# 40    2
# 41    2
# 43    2
# 45    2
# 46    2
# 47    2
# 48    2
# Name: patient_type, dtype: int64

# %% [markdown]
# #### 2. 두 번 이상 방문한 사람 특성 확인 후, 필요 시 삭제

# %%
# ID별 방문횟수 
df1['id'] = df1['id'].astype(str)
df1_sub = df1.copy()
df1_sub['visit'] = 1
# Out:
# C:\Users\Min\.conda\envs\my_python\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
VISIT_CNT = df1_sub.pivot_table(index = ['id'], values = ['visit'], aggfunc=np.sum)

# %%
VISIT_CNT2 = VISIT_CNT[VISIT_CNT.visit != 1] ; VISIT_CNT2
# Out:
#           visit
# id
# 0.00E+00     38
# 1.00E+47      2
# 1.00E+53      2
# 1.00E+84      2
# 1.00E+87      2
# ...         ...
# 7.00E+01      2
# 7.00E+02      2
# 7.00E+58      2
# 8.00E+41      2
# 8.60E+10      3
#
# [203 rows x 1 columns]

# %%
PERSON_BY_VISIT = VISIT_CNT2.groupby(['visit']).size(); PERSON_BY_VISIT
# Out:
# visit
# 2     155
# 3      42
# 4       5
# 38      1
# dtype: int64

# %% [markdown]
# - 두 번 이상 방문한 환자 203명; E 표기법으로 저장, 같은 ID 다른 성별임을 확인 — 동일인 X
# - 2번 이상 방문한 것으로 counting 되는 경우 row 모두 제거

# %%
df2 = pd.merge(df1, VISIT_CNT, on = ['id'])

df2 = df2[df2.visit == 1]    
df2[df2.visit != 1]
# Out:
# Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
#  #### 3. 남성에서 임신 여부 변수 97 (해당없음) → 2 (아니오) 로 변경

# %%
df2['pregnancy'] = df2['pregnancy'].apply(lambda x : 2 if x == 97 else x)

# %%
df2[df2.sex == 2]     # 남성 → 임신변수 모두 2로 변경됨 확인
# Out:
#               id  sex  patient_type  entry_date date_symptoms   date_died  \
# 1         0b5948    2             2  17-04-2020    10-04-2020  9999-99-99
# 3         1beec8    2             2  16-04-2020    16-04-2020  29-04-2020
# 4       1.75E+56    2             2  22-04-2020    13-04-2020  9999-99-99
# 7         126f5c    2             2  02-05-2020    02-05-2020  9999-99-99
# 11        0d968b    2             2  24-04-2020    21-04-2020  9999-99-99
# ...          ...  ...           ...         ...           ...         ...
# 121905    1c5d42    2             2  13-06-2020    13-06-2020  9999-99-99
# 121907    0f6881    2             2  21-06-2020    17-06-2020  9999-99-99
# 121908    093a47    2             2  02-05-2020    02-05-2020  9999-99-99
# 121909    067bbd    2             2  07-06-2020    24-05-2020  9999-99-99
# 121910  5.60E+40    2             2  08-05-2020    08-05-2020  13-05-2020
#
#         intubed  pneumonia  age  pregnancy  ...  hypertension  other_disease  \
# 1             2          1   30          2  ...             2              2
# 3             2          1   47          2  ...             2              2
# 4             2          2   63          2  ...             1              2
# 7             2          2   28          2  ...             2              2
# 11            2          2   56          2  ...             2              2
# ...         ...        ...  ...        ...  ...           ...            ...
# 121905        1          2   40          2  ...             2              1
# 121907        2          2   76          2  ...             1              2
# 121908        2          1   45          2  ...             2              2
# 121909        1          1   68          2  ...             1              2
# 121910        1          1   48          2  ...             1              2
#
#         cardiovascular  obesity  renal_chronic  tobacco  contact_other_covid  \
# 1                    2        2              2        2                   99
# 3                    2        2              2        2                   99
# 4                    2        2              2        2                   99
# 7                    2        2              2        2                   99
# 11                   2        2              2        2                   99
# ...                ...      ...            ...      ...                  ...
# 121905               2        2              2        2                   99
# 121907               2        2              2        2                   99
# 121908               2        2              2        2                   99
# 121909               2        1              2        2                    2
# 121910               2        2              2        2                    2
#
#         covid_res  icu  visit
# 1               1    2      1
# 3               1    1      1
# 4               1    2      1
# 7               1    2      1
# 11              1    2      1
# ...           ...  ...    ...
# 121905          3    1      1
# 121907          3    2      1
# 121908          3    2      1
# 121909          3    1      1
# 121910          3    1      1
#
# [72775 rows x 24 columns]

# %% [markdown]
# #### 4. 모든 변수 98, 99 → 3으로 변경

# %%
df3 = df2.copy()
for i in ['intubed', 'pregnancy','pneumonia', 'diabetes', 'copd', 'asthma', 'inmsupr', 'hypertension', 'other_disease', 'cardiovascular',
          'obesity', 'renal_chronic', 'tobacco', 'contact_other_covid', 'icu']:
    df3[i] = df3[i].apply(lambda x : 3 if x ==98 or x == 99 else x)

# %%
check = []
for i in ['intubed', 'pregnancy', 'pneumonia', 'diabetes', 'copd', 'asthma', 'inmsupr', 'hypertension', 'other_disease', 'cardiovascular', 'obesity', 'renal_chronic', 'tobacco' , 'contact_other_covid', 'icu']:
    check.append(df3[df3[i]==98])
print(check)
# Out:
# [Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns], Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit]
# Index: []
#
# [0 rows x 24 columns]]

# %% [markdown]
# #### 5. 사망여부 변수 추가
# - date_died = 99-99-9999인 경우: DEATH=0 (생존)
# - date_died 에 날짜가 입력되어 있는 경우: DEATH=1 (사망)

# %%
df4 = df3.copy()
df4['DEATH'] = np.where(df4['date_died']=='9999-99-99', 0, 1)

# %%
df4[df4.date_died == '9999-99-99'].DEATH
# Out:
# 0         0
# 1         0
# 4         0
# 5         0
# 6         0
#          ..
# 121907    0
# 121908    0
# 121909    0
# 121911    0
# 121912    0
# Name: DEATH, Length: 88993, dtype: int32

# %%
df4[df4.date_died != '9999-99-99'].DEATH
# Out:
# 2         1
# 3         1
# 12        1
# 14        1
# 16        1
#          ..
# 121899    1
# 121901    1
# 121902    1
# 121906    1
# 121910    1
# Name: DEATH, Length: 32426, dtype: int32

# %%
df4
# Out:
#               id  sex  patient_type  entry_date date_symptoms   date_died  \
# 0         167386    1             2  06-04-2020    01-04-2020  9999-99-99
# 1         0b5948    2             2  17-04-2020    10-04-2020  9999-99-99
# 2         0d01b5    1             2  13-04-2020    13-04-2020  22-04-2020
# 3         1beec8    2             2  16-04-2020    16-04-2020  29-04-2020
# 4       1.75E+56    2             2  22-04-2020    13-04-2020  9999-99-99
# ...          ...  ...           ...         ...           ...         ...
# 121908    093a47    2             2  02-05-2020    02-05-2020  9999-99-99
# 121909    067bbd    2             2  07-06-2020    24-05-2020  9999-99-99
# 121910  5.60E+40    2             2  08-05-2020    08-05-2020  13-05-2020
# 121911    150615    1             2  12-05-2020    09-05-2020  9999-99-99
# 121912    1beb81    1             2  14-05-2020    01-05-2020  9999-99-99
#
#         intubed  pneumonia  age  pregnancy  ...  other_disease  \
# 0             2          2   54          2  ...              2
# 1             2          1   30          2  ...              2
# 2             2          2   60          2  ...              2
# 3             2          1   47          2  ...              2
# 4             2          2   63          2  ...              2
# ...         ...        ...  ...        ...  ...            ...
# 121908        2          1   45          2  ...              2
# 121909        1          1   68          2  ...              2
# 121910        1          1   48          2  ...              2
# 121911        2          1   31          3  ...              2
# 121912        2          1   49          2  ...              2
#
#         cardiovascular  obesity  renal_chronic  tobacco  contact_other_covid  \
# 0                    2        1              2        2                    3
# 1                    2        2              2        2                    3
# 2                    1        2              2        2                    3
# 3                    2        2              2        2                    3
# 4                    2        2              2        2                    3
# ...                ...      ...            ...      ...                  ...
# 121908               2        2              2        2                    3
# 121909               2        1              2        2                    2
# 121910               2        2              2        2                    2
# 121911               2        2              2        2                    3
# 121912               2        1              2        2                    3
#
#         covid_res  icu  visit  DEATH
# 0               1    2      1      0
# 1               1    2      1      0
# 2               1    2      1      1
# 3               1    1      1      1
# 4               1    2      1      0
# ...           ...  ...    ...    ...
# 121908          3    2      1      0
# 121909          3    1      1      0
# 121910          3    1      1      1
# 121911          3    2      1      0
# 121912          3    2      1      0
#
# [121419 rows x 25 columns]

# %% [markdown]
# #### 6. 생존자 사망일 Imputation
# - Entry date, symptom date, death date 중 가장 마지막 날짜로 생존자 사망일 imputation
# - last_date로 새 변수 생성

# %%
entry = df4[df4.entry_date != '9999-99-99'].entry_date
sym = df4[df4.date_symptoms != '9999-99-99'].date_symptoms
dth = df4[df4.date_died != '9999-99-99'].date_died

# %%
tot_date = pd.concat([entry, sym, dth], ignore_index=True)
tot_date
# Out:
# 0         06-04-2020
# 1         17-04-2020
# 2         13-04-2020
# 3         16-04-2020
# 4         22-04-2020
#              ...
# 275259    13-05-2020
# 275260    19-06-2020
# 275261    05-06-2020
# 275262    14-06-2020
# 275263    13-05-2020
# Length: 275264, dtype: object

# %%
tot_date = pd.to_datetime(tot_date, format = '%d-%m-%Y')
tot_date
# Out:
# 0        2020-04-06
# 1        2020-04-17
# 2        2020-04-13
# 3        2020-04-16
# 4        2020-04-22
#             ...
# 275259   2020-05-13
# 275260   2020-06-19
# 275261   2020-06-05
# 275262   2020-06-14
# 275263   2020-05-13
# Length: 275264, dtype: datetime64[ns]

# %%
tot_date.max()     # 가장 최근날짜 2020-06-29
# Out:
# Timestamp('2020-06-29 00:00:00')

# %%
df5 = df4.copy()
df5['last_date'] = df4['date_died'].apply(lambda x : '29-06-2020' if x == '9999-99-99' else x)

# %%
df5[df5.DEATH == 0].last_date
# Out:
# 0         29-06-2020
# 1         29-06-2020
# 4         29-06-2020
# 5         29-06-2020
# 6         29-06-2020
#              ...
# 121907    29-06-2020
# 121908    29-06-2020
# 121909    29-06-2020
# 121911    29-06-2020
# 121912    29-06-2020
# Name: last_date, Length: 88993, dtype: object

# %% [markdown]
# #### 7. 날짜 이상인 사람 삭제하기

# %% [markdown]
# #### 1) symptom date가 entry date보다 늦은 사람 제거
# - entry_date - date_symptoms < 0

# %%
df6_sub1 = df5.copy()
df6_sub1['d_ent'] = pd.to_datetime(df6_sub1['entry_date'], format = "%d-%m-%Y") 
df6_sub1['d_sym'] = pd.to_datetime(df6_sub1['date_symptoms'], format = "%d-%m-%Y")
df6_sub1['d_last'] = pd.to_datetime(df6_sub1['last_date'], format = "%d-%m-%Y")
df6_sub1.head()
# Out:
#          id  sex  patient_type  entry_date date_symptoms   date_died  intubed  \
# 0    167386    1             2  06-04-2020    01-04-2020  9999-99-99        2
# 1    0b5948    2             2  17-04-2020    10-04-2020  9999-99-99        2
# 2    0d01b5    1             2  13-04-2020    13-04-2020  22-04-2020        2
# 3    1beec8    2             2  16-04-2020    16-04-2020  29-04-2020        2
# 4  1.75E+56    2             2  22-04-2020    13-04-2020  9999-99-99        2
#
#    pneumonia  age  pregnancy  ...  tobacco  contact_other_covid  covid_res  \
# 0          2   54          2  ...        2                    3          1
# 1          1   30          2  ...        2                    3          1
# 2          2   60          2  ...        2                    3          1
# 3          1   47          2  ...        2                    3          1
# 4          2   63          2  ...        2                    3          1
#
#    icu  visit  DEATH   last_date      d_ent      d_sym     d_last
# 0    2      1      0  29-06-2020 2020-04-06 2020-04-01 2020-06-29
# 1    2      1      0  29-06-2020 2020-04-17 2020-04-10 2020-06-29
# 2    2      1      1  22-04-2020 2020-04-13 2020-04-13 2020-04-22
# 3    1      1      1  29-04-2020 2020-04-16 2020-04-16 2020-04-29
# 4    2      1      0  29-06-2020 2020-04-22 2020-04-13 2020-06-29
#
# [5 rows x 29 columns]

# %%
df6_sub1['diff1'] = (df6_sub1['d_ent'] - df6_sub1['d_sym']).dt.days.astype(int)
df6_sub1 = df6_sub1[df6_sub1.diff1 >= 0]     # 제외 대상자 삭제 
df6_sub1[df6_sub1.diff1 < 0]                 # 잘 제거되었는지 확인
# Out:
# Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit, DEATH, last_date, d_ent, d_sym, d_last, diff1]
# Index: []
#
# [0 rows x 30 columns]

# %% [markdown]
# #### 2) entry date, symptom date이 last date 보다 늦은 사람 제거
# - last_date - date_symptoms < 0  또는 last_date - entry_date < 0

# %%
df6_sub2 = df6_sub1.copy()
df6_sub2['diff2'] = (df6_sub2['d_last'] - df6_sub2['d_sym']).dt.days.astype(int)
df6_sub2['diff3'] = (df6_sub2['d_last'] - df6_sub2['d_ent']).dt.days.astype(int)

# %% [markdown]
# ##### 제외 대상자삭제

# %%
df6_sub2 = df6_sub2[df6_sub2.diff2 >= 0]
df6_sub2 = df6_sub2[df6_sub2.diff3 >= 0]

# %%
df6_sub2[df6_sub2.diff2 < 0]
df6_sub2[df6_sub2.diff3 < 0]
# Out:
# Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit, DEATH, last_date, d_ent, d_sym, d_last, diff1, diff2, diff3]
# Index: []
#
# [0 rows x 32 columns]

# %%
df6 = df6_sub2.copy()
df6.head()
# Out:
#          id  sex  patient_type  entry_date date_symptoms   date_died  intubed  \
# 0    167386    1             2  06-04-2020    01-04-2020  9999-99-99        2
# 1    0b5948    2             2  17-04-2020    10-04-2020  9999-99-99        2
# 2    0d01b5    1             2  13-04-2020    13-04-2020  22-04-2020        2
# 3    1beec8    2             2  16-04-2020    16-04-2020  29-04-2020        2
# 4  1.75E+56    2             2  22-04-2020    13-04-2020  9999-99-99        2
#
#    pneumonia  age  pregnancy  ...  icu  visit  DEATH   last_date      d_ent  \
# 0          2   54          2  ...    2      1      0  29-06-2020 2020-04-06
# 1          1   30          2  ...    2      1      0  29-06-2020 2020-04-17
# 2          2   60          2  ...    2      1      1  22-04-2020 2020-04-13
# 3          1   47          2  ...    1      1      1  29-04-2020 2020-04-16
# 4          2   63          2  ...    2      1      0  29-06-2020 2020-04-22
#
#        d_sym     d_last  diff1  diff2  diff3
# 0 2020-04-01 2020-06-29      5     89     84
# 1 2020-04-10 2020-06-29      7     80     73
# 2 2020-04-13 2020-04-22      0      9      9
# 3 2020-04-16 2020-04-29      0     13     13
# 4 2020-04-13 2020-06-29      9     77     68
#
# [5 rows x 32 columns]

# %%
len(df6)
# Out:
# 121395

# %% [markdown]
# #### 8. 사망 또는 관찰기간 변수 생성
# - 사망한 사람은 증상발현~사망까지 기간
# - 생존한 사람은 증상발현~마지막관찰일(2020-06-29)까지 기간
# - d_last - d_sym

# %%
df6['diff_days'] = (df6.d_last - df6.d_sym).dt.days.astype(int)

# %%
df6.head()
# Out:
#          id  sex  patient_type  entry_date date_symptoms   date_died  intubed  \
# 0    167386    1             2  06-04-2020    01-04-2020  9999-99-99        2
# 1    0b5948    2             2  17-04-2020    10-04-2020  9999-99-99        2
# 2    0d01b5    1             2  13-04-2020    13-04-2020  22-04-2020        2
# 3    1beec8    2             2  16-04-2020    16-04-2020  29-04-2020        2
# 4  1.75E+56    2             2  22-04-2020    13-04-2020  9999-99-99        2
#
#    pneumonia  age  pregnancy  ...  visit  DEATH   last_date      d_ent  \
# 0          2   54          2  ...      1      0  29-06-2020 2020-04-06
# 1          1   30          2  ...      1      0  29-06-2020 2020-04-17
# 2          2   60          2  ...      1      1  22-04-2020 2020-04-13
# 3          1   47          2  ...      1      1  29-04-2020 2020-04-16
# 4          2   63          2  ...      1      0  29-06-2020 2020-04-22
#
#        d_sym     d_last  diff1  diff2  diff3  diff_days
# 0 2020-04-01 2020-06-29      5     89     84         89
# 1 2020-04-10 2020-06-29      7     80     73         80
# 2 2020-04-13 2020-04-22      0      9      9          9
# 3 2020-04-16 2020-04-29      0     13     13         13
# 4 2020-04-13 2020-06-29      9     77     68         77
#
# [5 rows x 33 columns]

# %%
df6['diff_days'].describe()
# Out:
# count    121395.000000
# mean         32.845092
# std          27.360004
# min           0.000000
# 25%          11.000000
# 50%          24.000000
# 75%          49.000000
# max         180.000000
# Name: diff_days, dtype: float64

# %%
df6[df6['diff_days'] < 0]
# Out:
# Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit, DEATH, last_date, d_ent, d_sym, d_last, diff1, diff2, diff3, diff_days]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# # 시각화

# %%
sns.distplot(df6[df6.DEATH==0]["diff_days"], label="survival")
sns.distplot(df6[df6.DEATH==1]["diff_days"], label="death")

plt.title("Follow-up Time By Group")
plt.legend(title="Group")
plt.xlabel("follow-up time(unit:days)")
plt.ylabel("Density")
plt.show()
# Out:
# C:\Users\Min\.conda\envs\my_python\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Min\.conda\envs\my_python\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##### 연령군 나누기 ()

# %%
df7 = df6.copy()

# %%
sns.distplot(df7[df7.DEATH==0]["age"], label="survival")
sns.distplot(df7[df7.DEATH==1]["age"], label="death")

plt.title("Age By Group")
plt.legend(title="Group")
plt.xlabel("age")
plt.ylabel("Density")
plt.show()
# Out:
# C:\Users\Min\.conda\envs\my_python\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Min\.conda\envs\my_python\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df7['age'].describe()
# Out:
# count    121395.000000
# mean         52.957577
# std          19.237785
# min           0.000000
# 25%          42.000000
# 50%          55.000000
# 75%          66.000000
# max         118.000000
# Name: age, dtype: float64

# %%
df7['age_grp'] = np.where(df7['age']<20, 1,
                          np.where(df7['age']<40, 2,
                                   np.where(df7['age']<60, 3,
                                            np.where(df7['age']<80, 4, 
                                                     np.where(df7['age']>=80, 5, np.nan)))))
df7[df7['age_grp'].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [id, sex, patient_type, entry_date, date_symptoms, date_died, intubed, pneumonia, age, pregnancy, diabetes, copd, asthma, inmsupr, hypertension, other_disease, cardiovascular, obesity, renal_chronic, tobacco, contact_other_covid, covid_res, icu, visit, DEATH, last_date, d_ent, d_sym, d_last, diff1, diff2, diff3, diff_days, age_grp]
# Index: []
#
# [0 rows x 34 columns]

# %% [markdown]
# ##### 연령 그룹 별 사람 수 확인

# %%
PERSON_BY_AGE = df7.groupby(['age_grp']).size(); PERSON_BY_AGE
# Out:
# age_grp
# 1.0     6632
# 2.0    19800
# 3.0    47384
# 4.0    39347
# 5.0     8232
# dtype: int64

# %% [markdown]
# ##### 분석에 필요없는 변수 삭제 후 Export

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121395 entries, 0 to 121912
# Data columns (total 34 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   121395 non-null  object
#  1   sex                  121395 non-null  int64
#  2   patient_type         121395 non-null  int64
#  3   entry_date           121395 non-null  object
#  4   date_symptoms        121395 non-null  object
#  5   date_died            121395 non-null  object
#  6   intubed              121395 non-null  int64
#  7   pneumonia            121395 non-null  int64
#  8   age                  121395 non-null  int64
#  9   pregnancy            121395 non-null  int64
#  10  diabetes             121395 non-null  int64
#  11  copd                 121395 non-null  int64
#  12  asthma               121395 non-null  int64
#  13  inmsupr              121395 non-null  int64
#  14  hypertension         121395 non-null  int64
#  15  other_disease        121395 non-null  int64
#  16  cardiovascular       121395 non-null  int64
#  17  obesity              121395 non-null  int64
#  18  renal_chronic        121395 non-null  int64
#  19  tobacco              121395 non-null  int64
#  20  contact_other_covid  121395 non-null  int64
#  21  covid_res            121395 non-null  int64
#  22  icu                  121395 non-null  int64
#  23  visit                121395 non-null  int64
#  24  DEATH                121395 non-null  int32
#  25  last_date            121395 non-null  object
#  26  d_ent                121395 non-null  datetime64[ns]
#  27  d_sym                121395 non-null  datetime64[ns]
#  28  d_last               121395 non-null  datetime64[ns]
#  29  diff1                121395 non-null  int32
#  30  diff2                121395 non-null  int32
#  31  diff3                121395 non-null  int32
#  32  diff_days            121395 non-null  int32
#  33  age_grp              121395 non-null  float64
# dtypes: datetime64[ns](3), float64(1), int32(5), int64(20), object(5)
# memory usage: 30.1+ MB

# %%
df8 = df7.loc[:, ['id', 'sex',  'intubed', 'pneumonia', 'age', 'pregnancy', 
                  'diabetes', 'copd', 'asthma', 'inmsupr', 'hypertension', 
                  'other_disease', 'obesity', 'cardiovascular', 'renal_chronic', 
                  'tobacco', 'contact_other_covid', 'covid_res','icu', 'DEATH',
                  'd_ent', 'd_sym', 'd_last', 'diff_days', 'age_grp']]
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121395 entries, 0 to 121912
# Data columns (total 25 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   121395 non-null  object
#  1   sex                  121395 non-null  int64
#  2   intubed              121395 non-null  int64
#  3   pneumonia            121395 non-null  int64
#  4   age                  121395 non-null  int64
#  5   pregnancy            121395 non-null  int64
#  6   diabetes             121395 non-null  int64
#  7   copd                 121395 non-null  int64
#  8   asthma               121395 non-null  int64
#  9   inmsupr              121395 non-null  int64
#  10  hypertension         121395 non-null  int64
#  11  other_disease        121395 non-null  int64
#  12  obesity              121395 non-null  int64
#  13  cardiovascular       121395 non-null  int64
#  14  renal_chronic        121395 non-null  int64
#  15  tobacco              121395 non-null  int64
#  16  contact_other_covid  121395 non-null  int64
#  17  covid_res            121395 non-null  int64
#  18  icu                  121395 non-null  int64
#  19  DEATH                121395 non-null  int32
#  20  d_ent                121395 non-null  datetime64[ns]
#  21  d_sym                121395 non-null  datetime64[ns]
#  22  d_last               121395 non-null  datetime64[ns]
#  23  diff_days            121395 non-null  int32
#  24  age_grp              121395 non-null  float64
# dtypes: datetime64[ns](3), float64(1), int32(2), int64(18), object(1)
# memory usage: 23.2+ MB

# %%
df8.to_csv('d_final.csv', encoding='utf-8', index=False, line_terminator='\n')
